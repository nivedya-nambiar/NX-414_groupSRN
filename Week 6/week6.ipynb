# %% [markdown]
# ## NX-414: Brain-like computation and intelligence
# Notebook prepared by Alessandro Marin Vargas

# %% [markdown]
# # Week 6 - Mini project (Predicting neural activity)
#
# The objectives of the mini project are:
# - Learn how to predict neural activity using linear regression from images and from neural network layers.
# - Quantify the goodness of the model
# - Compare the results across the network layers and between trained/random neural network
# - Predict the neural activity using a neural network in a data-driven approach
#
# Specifically, here you will use the data from the following [paper](https://www.jneurosci.org/content/jneuro/35/39/13402.full.pdf). The behavioral experiment consisted in showing to non-human primates some images while recording the neural activity with multielectrode arrays from the inferior temporal (IT) cortex. In the data we provided you, the neural activity and the images are already pre-processed and you will have available the images and the corresponding average firing rate (between 70 and 170 ms) per each neuron.
#
# ### Deadline for Mini-Project Submission: May 7, 2025
#
# You are required to submit your mini-projects by midnight on 07/05/25. Please upload a .zip file to Moodle containing your code, along with the following specific components:
#
# - One-Page Report (Report.pdf): This should detail your investigative process and include:
#     - A comparison table of models. This should cover linear regression from stimuli, both trained and random task-driven models, data-driven models, and your best-performing model.
#     - A figure illustrating the variation in neural prediction across different layers of a task-driven model.
#     - Your exploration to develop the most effective model at predicting IT neural activity
# - Example Script/Notebook: Please provide a script (test.py) or a notebook (test.ipynb) demonstrating how your best model performs on the validation set. This should serve as an example of the model's usage.

# %%
import sys
# !{sys.executable} -m pip install gdown h5py

# %%
from utils import load_it_data, visualize_img, save_pkl, load_pkl
import matplotlib.pyplot as plt
import numpy as np

# %%
import gdown
url = "https://drive.google.com/file/d/1s6caFNRpyR9m7ZM6XEv_e8mcXT3_PnHS/view?usp=share_link"
output = "IT_data.h5"
gdown.download(url, output, quiet=False, fuzzy=True)

# %% [markdown]
# ### Load the data

# %%
path_to_data = '' ## Insert the folder where the data is, if you download in the same folder as this notebook then leave it blank

stimulus_train, stimulus_val, stimulus_test, objects_train, objects_val, objects_test, spikes_train, spikes_val = load_it_data(path_to_data)

# %%
print("stimulus_train shape: ", stimulus_train.shape)
print("stimulus_val shape: ", stimulus_val.shape)
print("stimulus_test shape: ", stimulus_val.shape)
print("objects_train shape: ", len(objects_train))
print("objects_val shape: ", len(objects_val))
print("objects_val shape: ", len(objects_test))
print("spikes_train shape: ", spikes_train.shape)
print("spikes_val shape: ", spikes_val.shape)
# Out:
# stimulus_train shape:  (2592, 3, 224, 224)
# stimulus_val shape:  (288, 3, 224, 224)
# stimulus_test shape:  (288, 3, 224, 224)
# objects_train shape:  2592
# objects_val shape:  288
# objects_val shape:  320
# spikes_train shape:  (2592, 168)
# spikes_val shape:  (288, 168)

# %%
print(objects_train)
print(objects_val)
print(objects_test)
# Out:
# ['face6', 'table3', 'face3', 'face2', 'lioness', 'turtle', 'turtle', 'airplane3', 'cow', 'car_alfa', 'table2', 'ship1', 'car_bora', 'airplane3', 'face6', 'chair4', 'airplane0', 'airplane6', 'chair2', 'car_alfa', 'gorilla', 'chair4', 'raspberry', 'pear', 'chair5', 'face0', 'table5', 'table1', 'airplane5', 'airplane2', 'table7', 'chair0', 'chair7', 'face7', 'car_beetle', 'ship7', 'table0', 'chair7', 'airplane4', 'car_z3', 'chair7', 'lioness', 'table5', 'walnut', 'chair5', 'chair4', 'chair3', 'elephant', 'car_alfa', 'table4', 'car_clio', 'ship2', 'apple', 'airplane2', 'face1', 'chair7', 'watermelon', 'airplane0', 'walnut', 'watermelon', 'dog', 'airplane7', 'ship1', 'apple', 'ship7', 'ship6', 'ship2', 'pear', 'car_bmw', 'car_alfa', 'face0', 'ship1', 'ship7', 'table1', 'car_bora', 'car_alfa', 'watermelon', 'pear', 'car_celica', 'apple', 'chair7', 'table0', 'car_clio', 'airplane7', 'car_beetle', 'apricot', 'table1', 'chair0', 'car_bora', 'hedgehog', 'ship6', 'airplane4', 'chair2', 'car_z3'
# ...

# %%
def get_category(label):
    if 'face' in label:
        return 'face'
    elif 'table' in label:
        return 'table'
    elif 'ship' in label:
        return 'boat'
    elif 'car' in label:
        return 'car'
    elif 'chair' in label:
        return 'chair'
    elif 'airplane' in label:
        return 'plane'
    elif label in ['cow', 'lioness', 'dog', 'gorilla', 'turtle', 'elephant', 'hedgehog', 'bear']:  # animals
        return 'animal'
    elif label in ['watermelon', 'walnut', 'raspberry', 'pear', 'peach', 'apricot', 'apple', 'strawberry']:  # fruits
        return 'fruit'
    else:
        return 'unknown'

# %%
y_classes = [(obj,get_category(obj)) for obj in objects_train]
print(y_classes.count("unknown"))
print(y_classes)

others = [obj for obj in objects_train if get_category(obj) == 'unknown']
print(set(others))
# Out:
# 0
# ...

# %%
n_stimulus, n_channels, img_size, _ = stimulus_train.shape
print(_)
_, n_neurons = spikes_train.shape
# print(_)
print('The train dataset contains {} stimuli and {} IT neurons'.format(n_stimulus,n_neurons))
print('Each stimulus have {} channgels (RGB)'.format(n_channels))
print('The size of the image is {}x{}'.format(img_size,img_size))
# Out:
# 224
# The train dataset contains 2592 stimuli and 168 IT neurons
# Each stimulus have 3 channgels (RGB)
# The size of the image is 224x224

# %%
stim_idx = 0

visualize_img(stimulus_train,objects_train,stim_idx)

# %%
neuron_idx = 1

plt.figure()
plt.title('Average firing rate for neuron {} (70-170 ms)'.format(neuron_idx))
plt.plot(spikes_train[:,neuron_idx])

# %%
spikes_train.shape

# %% [markdown]
# ## Part 1: Predict the neural activity from pixels
#
# ##### Develop a linear regression model that predict the neural activity from pixels.
# You can try out different types of linear regression (ridge, least-square regression)

# %%
# %pip install scikit-learn

# %% [markdown]
# ### Train-test split

# %%
# # for train-test split

# from sklearn.model_selection import train_test_split
# # Split the data into training and test sets
# X_train, X_test, y_train, y_test = train_test_split(stimulus_train.reshape(n_stimulus, -1), spikes_train, test_size=0.2, random_state=42)

# %% [markdown]
# ### Linear regression

# %%
#least-square regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
flatten_stimulus_train = stimulus_train.reshape(n_stimulus, -1)
# flatten_stimulus_test = stimulus_test.reshape(stimulus_test.shape[0], -1)
flatten_stimulus_val = stimulus_val.reshape(stimulus_val.shape[0], -1)

# %% [markdown]
# #### Fit the Model

# %%
# Fit a linear regression model
lr_model_train = LinearRegression().fit(flatten_stimulus_train, spikes_train)

# %%
# Make predictions on the test set
lr_y_pred_val = lr_model_train.predict(flatten_stimulus_val)

# %% [markdown]
# #### Save the Model and the Predictions

# %%
save_pkl(lr_model_train, 'lr_model_train.pkl')
save_pkl(lr_y_pred_val, 'lr_y_val.pkl')

# %% [markdown]
# ---
# #### (Load the Model and Predictions)

# %%
lr_model_train = load_pkl('lr_model_train.pkl')
lr_y_pred_val = load_pkl('lr_y_val.pkl')

# %% [markdown]
# ---

# %% [markdown]
# ### Ridge Regression

# %%
# ridge regression
from sklearn.linear_model import Ridge

# %% [markdown]
# #### Fit the Model

# %%
rr_model_train = Ridge(alpha=1).fit(flatten_stimulus_train, spikes_train)

# %%
# Make predictions on the test set
rr_y_pred_val = rr_model_train.predict(flatten_stimulus_val)

# %% [markdown]
# #### Save the Model and the Predictions

# %%
save_pkl(rr_model_train, 'rr_model_train.pkl')
save_pkl(rr_y_pred_val, 'rr_y_pred_val.pkl')

# %% [markdown]
# ---
# #### (Load the Model and Predictions)

# %%
rr_model_train = load_pkl('rr_model_train.pkl')
rr_y_pred_val = load_pkl('rr_y_pred_val.pkl')

# %% [markdown]
# ---

# %% [markdown]
# ##### Evaluate your prediction (Check both the correlation and explained variance for each neuron). Plot the distribution for the explained variance across neurons.

# %% [markdown]
# #### Mean Squared Error (MSE)

# %%
# Calculate the mean squared error
lr_mse = mean_squared_error(spikes_val, lr_y_pred_val)
rr_mse = mean_squared_error(spikes_val, rr_y_pred_val)
print('Mean squared error (linear regression): ', lr_mse)
print('Mean squared error (ridge regression): ', rr_mse)
# Out:
# Mean squared error (linear regression):  0.1429024040699005
# Mean squared error (ridge regression):  0.2851778268814087

# %% [markdown]
# #### Correlation Coefficient (CC)

# %%
from scipy.stats import pearsonr

def mean_correlation(y_true, y_pred):
    correlations = []
    for i in range(y_true.shape[1]):
        corr, _ = pearsonr(y_true[:, i], y_pred[:, i])
        correlations.append(corr)
    return np.mean(correlations)

# %%
def cor_dis_plot(y_true, y_pred_lr, y_pred_rr):
    cor_per_neuron = lambda y_true, y_pred: np.array([pearsonr(y_true[:, i], y_pred[:, i])[0] for i in range(y_true.shape[1])])
    lr_corr_per_neuron = cor_per_neuron(y_true, y_pred_lr)
    rr_corr_per_neuron = cor_per_neuron(y_true, y_pred_rr)
    
    print(f"Mean correlation (linear regression): {np.mean(lr_corr_per_neuron)}")
    print(f"Mean correlation (ridge regression): {np.mean(rr_corr_per_neuron)}")
    
    all_vals = np.concatenate([lr_corr_per_neuron, rr_corr_per_neuron])
    bins = np.linspace(np.min(all_vals), np.max(all_vals), 30)
    
    plt.hist(lr_corr_per_neuron, bins=30, alpha=0.7, label='Linear')
    plt.hist(rr_corr_per_neuron, bins=30, alpha=0.7, label='Ridge')
    plt.xlabel('Correlation Coefficient (Pearson r)')
    plt.ylabel('Number of Neurons')
    plt.title('Distribution of Correlation per Neuron')
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
cor_dis_plot(spikes_val, lr_y_pred_val, rr_y_pred_val)
# Out:
# Mean correlation (linear regression): 0.21750061213970184
# Mean correlation (ridge regression): 0.14668689668178558

# %% [markdown]
# #### Explained Variance (EV)

# %%
# Calculate the explained variance score
from sklearn.metrics import explained_variance_score

# %%
lr_explained_variance = explained_variance_score(spikes_val, lr_y_pred_val)
rr_explained_variance = explained_variance_score(spikes_val, rr_y_pred_val)
print('Explained variance score (linear regression): ', lr_explained_variance)
print('Explained variance score (ridge regression): ', rr_explained_variance)
# Out:
# Explained variance score (linear regression):  -0.03340144455432892
# Explained variance score (ridge regression):  -1.1573759317398071

# %%
# try to see the trained explained variance
lr_explained_variance_train = explained_variance_score(spikes_train, lr_model_train.predict(flatten_stimulus_train))
rr_explained_variance_train = explained_variance_score(spikes_train, rr_model_train.predict(flatten_stimulus_train))
print('Explained variance score (linear regression): ', lr_explained_variance_train)
print('Explained variance score (ridge regression): ', rr_explained_variance_train)
# Out:
# Explained variance score (linear regression):  0.35492661595344543
# Explained variance score (ridge regression):  0.9999988079071045

# %%
def ev_dis_plot(y_true, y_pred_lr, y_pred_rr, title = 'Distribution of Explained Variance per Neuron'):

    # Compute per-neuron explained variance
    lr_ev_per_neuron = explained_variance_score(y_true, y_pred_lr, multioutput='raw_values')
    rr_ev_per_neuron = explained_variance_score(y_true, y_pred_rr, multioutput='raw_values')
    
    print(f"Mean explained variance (linear regression): {np.mean(lr_ev_per_neuron)}")
    print(f"Mean explained variance (ridge regression): {np.mean(rr_ev_per_neuron)}")

    lr_ev_per_neuron.shape = (168,)  # one value per neuron
    
    all_vals = np.concatenate([lr_ev_per_neuron, rr_ev_per_neuron])
    bins = np.linspace(np.min(all_vals), np.max(all_vals), 30)

    # plt.hist(lr_ev_per_neuron, bins=30, alpha=0.7, label='Linear')
    # plt.hist(rr_ev_per_neuron, bins=30 if (np.max(rr_ev_per_neuron)-np.min(rr_ev_per_neuron)>0.05) else 5, alpha=0.7, label='Ridge')
    plt.hist(lr_ev_per_neuron, bins=bins, alpha=0.7, label='Linear')
    plt.hist(rr_ev_per_neuron, bins=bins, alpha=0.7, label='Ridge')
    plt.xlabel('Explained Variance')
    plt.ylabel('Number of Neurons')
    plt.title(title)
    plt.legend()
    plt.grid(True)
    plt.show()

# %%
ev_dis_plot(spikes_val, lr_y_pred_val, rr_y_pred_val)
# Out:
# Mean explained variance (linear regression): -0.03340144455432892
# Mean explained variance (ridge regression): -1.1573759317398071

# %%
# try to see the training dataset explained variance
lr_model_train_pred = lr_model_train.predict(flatten_stimulus_train)
rr_model_train_pred = rr_model_train.predict(flatten_stimulus_train)

# %%
ev_dis_plot(spikes_train, lr_model_train_pred, rr_model_train_pred, title = 'Distribution of Explained Variance per Neuron (Training Dataset)')
# Out:
# Mean explained variance (linear regression): 0.35492661595344543
# Mean explained variance (ridge regression): 0.9999988079071045

# %% [markdown]
# ##### Predicting from pixels is very hard and the model is likely to overfit. An image is very high-dimensional, try to retain the corresponding 1000 PCs and use them to predict the neural activity.

# %%
from sklearn.decomposition import PCA

# %%
# Perform PCA on the training data
pca = PCA(n_components=1000)
X_train_pca = pca.fit_transform(flatten_stimulus_train)
X_val_pca = pca.transform(flatten_stimulus_val)

# %%
# save PCA model
save_pkl(pca, 'pca_model.pkl')
# save PCA data
save_pkl(X_train_pca, 'X_train_pca.pkl')
save_pkl(X_val_pca, 'X_val_pca.pkl')

# %%
# load PCA model
pca = load_pkl('pca_model.pkl')
# load PCA data
X_train_pca = load_pkl('X_train_pca.pkl')
X_val_pca = load_pkl('X_val_pca.pkl')

# %%
np.sum(pca.explained_variance_ratio_)

# %%
# Fit a linear regression model on the PCA-transformed data
lr_model_train_pca = LinearRegression().fit(X_train_pca, spikes_train)
# Make predictions on the test set
lr_y_pred_val_pca = lr_model_train_pca.predict(X_val_pca)

# %%
rr_model_train_pca = Ridge(alpha=1).fit(X_train_pca, spikes_train)
rr_y_pred_val_pca = rr_model_train_pca.predict(X_val_pca)

# %%
# Save the model and predictions
save_pkl(lr_model_train_pca, 'lr_model_train_pca.pkl')
save_pkl(lr_y_pred_val_pca, 'lr_y_pred_val_pca.pkl')

save_pkl(rr_model_train_pca, 'rr_model_train_pca.pkl')
save_pkl(rr_y_pred_val_pca, 'rr_y_pred_val_pca.pkl')

# %%
# Load the model and predictions
lr_model_train_pca = load_pkl('lr_model_train_pca.pkl')
lr_y_pred_val_pca = load_pkl('lr_y_pred_val_pca.pkl')

rr_model_train_pca = load_pkl('rr_model_train_pca.pkl')
rr_y_pred_val_pca = load_pkl('rr_y_pred_val_pca.pkl')

# %%
# mse
lr_mse_pca = mean_squared_error(spikes_val, lr_y_pred_val_pca)
rr_mse_pca = mean_squared_error(spikes_val, rr_y_pred_val_pca)
print('Mean squared error of PCA data (linear regression): ', lr_mse_pca)
print('Mean squared error of PCA data (ridge regression): ', rr_mse_pca)
# correlation
lr_correlation_pca = calculate_correlation(spikes_val, lr_y_pred_val_pca)
rr_correlation_pca = calculate_correlation(spikes_val, rr_y_pred_val_pca)
print('Correlation coefficient of PCA data (linear regression): ', lr_correlation_pca)
print('Correlation coefficient of PCA data (ridge regression): ', rr_correlation_pca)
#ev
lr_explained_variance_pca = explained_variance_score(spikes_val, lr_y_pred_val_pca)
rr_explained_variance_pca = explained_variance_score(spikes_val, rr_y_pred_val_pca)
print('Explained variance score of PCA data (linear regression): ', lr_explained_variance_pca)
print('Explained variance score of PCA data (ridge regression): ', rr_explained_variance_pca)

# %%
import matplotlib.pyplot as plt

# Compute per-neuron explained variance
lr_ev_per_neuron = explained_variance_score(spikes_val, lr_y_pred_val_pca, multioutput='raw_values')
rr_ev_per_neuron = explained_variance_score(spikes_val, rr_y_pred_val_pca, multioutput='raw_values')

lr_ev_per_neuron.shape = (168,)  # one value per neuron

plt.hist(lr_ev_per_neuron, bins=30, alpha=0.7, label='Linear')
plt.hist(rr_ev_per_neuron, bins=30, alpha=0.7, label='Ridge')
plt.xlabel('Explained Variance')
plt.ylabel('Number of Neurons')
plt.title('Distribution of Explained Variance per Neuron')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ##### Can we improve the prediction? Using the ridge regression, find the best parameter with cross-fold validation (remember to split the data keeping the same distribution of classes between the train and validation set). Does it get better?

# %%
y_classes = [get_category(obj) for obj in objects_train]

from sklearn.linear_model import Ridge
from sklearn.model_selection import StratifiedKFold, GridSearchCV

ridge = Ridge()

param_grid = {
    'alpha': [0.01, 0.1, 1, 10, 100]  # Or np.logspace(-2, 2, 10)
}

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

grid = GridSearchCV(
    estimator=ridge,
    param_grid=param_grid,
    cv=skf.split(flatten_stimulus_train, y_classes),
    scoring='explained_variance'
)

grid.fit(flatten_stimulus_train, spikes_train)

# %%
best_alpha = grid.best_params_['alpha']
best_model = grid.best_estimator_

# %%
best_alpha

# %%
best_model

# %%
rr_model_train_100 = Ridge(alpha=100).fit(flatten_stimulus_train, spikes_train)

# %%
rr_y_pred_val_100 = rr_model_train_100.predict(flatten_stimulus_val)

# %%
rr_100_mse = mean_squared_error(spikes_val, rr_y_pred_val_100)
print('Mean squared error (ridge regression): ', rr_100_mse)

rr_100_correlation = calculate_correlation(spikes_val, rr_y_pred_val_100)
print('Correlation coefficient (ridge regression): ', rr_100_correlation)

rr_100_explained_variance = explained_variance_score(spikes_val, rr_y_pred_val_100)
print('Explained variance score (ridge regression): ', rr_100_explained_variance)

# %%
import matplotlib.pyplot as plt

# Compute per-neuron explained variance
rr_ev_per_neuron = explained_variance_score(spikes_val, rr_y_pred_val_100, multioutput='raw_values')

# lr_ev_per_neuron.shape = (168,)  # one value per neuron

plt.hist(rr_ev_per_neuron, bins=30, alpha=0.7, label='Ridge')
plt.xlabel('Explained Variance')
plt.ylabel('Number of Neurons')
plt.title('Distribution of Explained Variance per Neuron')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Part 2: Predict the neural activity with the task-driven modeling approach
#
# As you have seen in the class, the underlying hypothesis of task-driven modeling is that training the network to perform a relevant behavioral task makes the network to develop representations that resemble the ones of the biological brain. Let's test this hypothesis by loading a pre-trained ResNet50 model and use the activations of each layer to predict the neural activity. Follow these steps:
#
# - Give as input to the network the stimuli and extract the corresponding activations of the following layers ['conv1','layer1','layer2','layer3','layer4','avgpool']
# - Compute the 1000 PCs for each layer activation. (Careful that you don't want to store all activations together at the same time because it won't fit in the memory. Therefore, compute the activations and corresponding PCs for each layer and store only the computed PCs).
# - Use the PCs of each layer to predict the neural activity using the linear regression models you developed before.
# - Compute the goodness of fit using the correlation and explained variance metrics. Do you predict the neural activity better than before?
# - Plot the distribution of explained variance with respect to the layer of the network (order them based on the depth). How does the neural activity changes across the model layers, can you make some statements about it?
# - Compare the predictions that you obtained using one layer of the pretrained model and the one obtained using the same layer but from a randomly initialized model. Which network can better predict the neural activity and why?

# %%
# %pip install torch
# %pip install torchvision

# %%
import torch
import torchvision.models as models
from torchvision import transforms

# %%
isinstance(stimulus_train, torch.Tensor)

# %%
stimulus_train_tensor = torch.from_numpy(stimulus_train).float()
isinstance(stimulus_train_tensor, torch.Tensor)

# %%
# %pip install torch
# %pip install torchvision

# %%
from torch.utils.data import DataLoader, TensorDataset

# %%
dataset = TensorDataset(stimulus_train_tensor)
dataloader = DataLoader(dataset, batch_size=32, shuffle=False)

# %%
stimulus_val_tensor = torch.from_numpy(stimulus_val).float()
dataset_val = TensorDataset(stimulus_val_tensor)
dataloader_val = DataLoader(dataset_val, batch_size=32, shuffle=False)

# %%
resnet = models.resnet50(pretrained=True)
resnet.eval()  # set to evaluation mode

# %%
activations = {}

def get_activation(name):
    def hook(model, input, output):
        activations[name] = output.detach()
    return hook

# Register hooks
resnet.conv1.register_forward_hook(get_activation('conv1'))
resnet.layer1.register_forward_hook(get_activation('layer1'))
resnet.layer2.register_forward_hook(get_activation('layer2'))
resnet.layer3.register_forward_hook(get_activation('layer3'))
resnet.layer4.register_forward_hook(get_activation('layer4'))
resnet.avgpool.register_forward_hook(get_activation('avgpool'))

# %%
activations_val = {}

def get_activation_val(name):
    def hook_val(model, input, output):
        activations_val[name] = output.detach()
    return hook_val

# Register hooks
resnet.conv1.register_forward_hook(get_activation_val('conv1'))
resnet.layer1.register_forward_hook(get_activation_val('layer1'))
resnet.layer2.register_forward_hook(get_activation_val('layer2'))
resnet.layer3.register_forward_hook(get_activation_val('layer3'))
resnet.layer4.register_forward_hook(get_activation_val('layer4'))
resnet.avgpool.register_forward_hook(get_activation_val('avgpool'))

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"device: {device}")

resnet = resnet.to(device)
stimulus_train_tensor = stimulus_train_tensor.to(device)

layers = ['conv1','layer1','layer2','layer3','layer4','avgpool']


for layer in layers:
    all_activations_layer = []
    with torch.no_grad():
        for batch in dataloader:
            inputs = batch[0].to(device)  # shape: (batch_size, 3, 224, 224)
            _ = resnet(inputs)  # triggers hooks
            
            batch_activations = activations[layer]  # shape: (batch_size, C, H, W)
            flattened = batch_activations.flatten(start_dim=1).cpu().numpy()
            all_activations_layer.append(flattened)

    all_activations_layer = np.vstack(all_activations_layer)  # shape: (2592, N)
    save_pkl(all_activations_layer, f"all_activations_{layer}.pkl")

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"device: {device}")

resnet = resnet.to(device)
stimulus_val_tensor = stimulus_val_tensor.to(device)

layers = ['conv1','layer1','layer2','layer3','layer4','avgpool']


for layer in layers:
    all_activations_layer = []
    with torch.no_grad():
        for batch in dataloader_val:
            inputs = batch[0].to(device)  # shape: (batch_size, 3, 224, 224)
            _ = resnet(inputs)  # triggers hooks
            
            batch_activations = activations_val[layer]  # shape: (batch_size, C, H, W)
            flattened = batch_activations.flatten(start_dim=1).cpu().numpy()
            all_activations_layer.append(flattened)

    all_activations_layer = np.vstack(all_activations_layer)  # shape: (2592, N)
    save_pkl(all_activations_layer, f"all_activations_{layer}_val.pkl")

# %%
from sklearn.decomposition import PCA
from utils import load_it_data, visualize_img, save_pkl, load_pkl

layers = ['conv1','layer1','layer2','layer3','layer4','avgpool']

for layer in layers:
    # Load pre-saved activation (NumPy array)
    pca = PCA(n_components=1000)
    activations = load_pkl(f"all_activations_{layer}.pkl")  # shape (2592, N)
    activations_val = load_pkl(f"all_activations_{layer}_val.pkl")  # shape (2592, N)
    X_pca = pca.fit_transform(activations)
    X_pca_val = pca.transform(activations_val)
    # Save PCA components
    save_pkl(pca, f"pca_{layer}.pkl")
    save_pkl(X_pca, f"X_pca_{layer}.pkl")
    save_pkl(X_pca_val, f"X_pca_{layer}_val.pkl")

# %%
X_pca_conv1 = load_pkl("X_pca_conv1.pkl")
X_pca_layer1 = load_pkl("X_pca_layer1.pkl")
X_pca_layer2 = load_pkl("X_pca_layer2.pkl")
X_pca_layer3 = load_pkl("X_pca_layer3.pkl")
X_pca_layer4 = load_pkl("X_pca_layer4.pkl")
X_pca_avgpool = load_pkl("X_pca_avgpool.pkl")

X_pca_conv1_val = load_pkl("X_pca_conv1_val.pkl")
X_pca_layer1_val = load_pkl("X_pca_layer1_val.pkl")
X_pca_layer2_val = load_pkl("X_pca_layer2_val.pkl")
X_pca_layer3_val = load_pkl("X_pca_layer3_val.pkl")
X_pca_layer4_val = load_pkl("X_pca_layer4_val.pkl")
X_pca_avgpool_val = load_pkl("X_pca_avgpool_val.pkl")

# %% [markdown]
# # conv

# %%
# Fit a linear regression model on the PCA-transformed data
lr_pca_conv1 = LinearRegression().fit(X_pca_conv1, spikes_train)
# Make predictions on the test set
lr_y_pred_conv1 = lr_pca_conv1.predict(X_pca_conv1_val)

# %%
# mse
lr_mse_pca = mean_squared_error(spikes_val, lr_y_pred_conv1)
print('Mean squared error of PCA data (linear regression): ', lr_mse_pca)
# correlation
lr_correlation_pca = calculate_correlation(spikes_val, lr_y_pred_conv1)
print('Correlation coefficient of PCA data (ridge regression): ', lr_correlation_pca)
#ev
lr_explained_variance_pca = explained_variance_score(spikes_val, lr_y_pred_conv1)
print('Explained variance score of PCA data (linear regression): ', lr_explained_variance_pca)

# %% [markdown]
# # avgpool

# %%
# Fit a linear regression model on the PCA-transformed data
lr_pca_avgpool = LinearRegression().fit(X_pca_avgpool, spikes_train)
# Make predictions on the test set
lr_y_pred_avgpool = lr_pca_avgpool.predict(X_pca_avgpool_val)

# %%
# mse
lr_mse_pca = mean_squared_error(spikes_val, lr_y_pred_avgpool)
print('Mean squared error of PCA data (linear regression): ', lr_mse_pca)
# correlation
lr_correlation_pca = calculate_correlation(spikes_val, lr_y_pred_avgpool)
print('Correlation coefficient of PCA data (ridge regression): ', lr_correlation_pca)
#ev
lr_explained_variance_pca = explained_variance_score(spikes_val, lr_y_pred_avgpool)
print('Explained variance score of PCA data (linear regression): ', lr_explained_variance_pca)
